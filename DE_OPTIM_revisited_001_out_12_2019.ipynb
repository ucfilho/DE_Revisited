# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/DE_Revisited/blob/master/DE_OPTIM_revisited_001_out_12_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
############################### Importar códigos

# !git clone https://github.com/ucfilho/DE_Revisited/ #clonar do Github
# Out:
# fatal: destination path 'DE_Revisited' already exists and is not an empty directory.

# %%
# 1. Preparation 2. Incubation 3. Insight 4. Evaluation 5. Elaboration

# %%
# %cd DE_Revisited
#!ls
# Out:
# /content/DE_Revisited

# %%
def fobj_de(x):
  global MAX,MIN, mut, crossp, NPAR, its,Fun,X,SOMA,TOTAL,ITE,PARTIC
  x=PARTIC
  ind_mut=ITE-1
  ind_crossp=2*ITE-1
  for k in range(ITE):
    ind_mut=ind_mut+1
    ind_crossp=ind_crossp+1
    #print("ind_mut",ind_mut)
    #print("ind_crossp",ind_crossp)
    #print("x",x)
    print("k=",k)
    NPAR=np.copy(int(x[k]))
    print("NPAR=",NPAR)
    mut=np.copy(x[ind_mut])
    crossp=np.copy(x[ind_crossp])
    X,BEST,FOBEST,XY,BEST_XY,SOMA= de_soma_fixa.de(MAX,MIN, mut, crossp, 
                                                            NPAR, its,Fun,X,SOMA,
                                                            TOTAL)
    
  return FOBEST

# %%
############################### Importar bibliotecas e iniciar a contagem do tempo
import time
import matplotlib.pyplot as plt
import numpy as np
from random import randint
from scipy import optimize
#import de_rotina_out_11_2019
import de_revisited_bounds
import de_soma_fixa
############################### Importar códigos
'''
# !git clone https://github.com/RaianaSeixas/GERENCIADOR.git #clonar do Github

# %cd
# %cd /content/GERENCIADOR
# !ls
'''
############################### DADOS DE ENTRADA 
RUNS=1 #NÚMERO DE RODADAS
#mut=0.8
#crossp=0.7
  ############################### Função
import Function

'''
Fun=Function.Rosenbrock
dim=30
MAX=np.repeat(10,dim)
MIN=np.repeat(-10,dim)

  #Global optimum: f(xi)= 0
'''
'''
dim=30
Fun=Function.Sphere
MAX=np.repeat(5.12,dim)
MIN=np.repeat(-5.12,dim)
  # f(x)=0 x=(0,0) [-5.12,5.12]
'''
#'''
dim=3
Fun=Function.Schwefel
MAX=np.repeat(500,dim)
MIN=np.repeat(-500,dim)
  #Global optimum: f(xi)= 0 for xi = 420.968746 for i=1,...,n  ;  xi in [-500,500]  
#'''
'''
dim=30
Fun=Function.Rastrigin
MAX=np.repeat(5.12,dim)
MIN=np.repeat(-5.12,dim)
  # f(x)=0 x=(0,0) [-5.12,5.12]
'''
'''
dim=30
Fun=Function.Sum_of_different_powers
MAX=np.repeat(1,dim)
MIN=np.repeat(-1,dim)
  # f(x)=0 x=(0,0)
'''
'''  
dim=30
Fun=Function.Ackley
MAX=np.repeat(32,dim)
MIN=np.repeat(-32,dim)
 # f(x)=0 x=(0,0) [-32, 32]
'''
'''  
dim=30
Fun=Function.Michalewicz
MAX=np.repeat(np.pi,dim)
MIN=np.repeat(0,dim)
 #fx=-9.66015 p/ d=10 [0,pi]
'''
'''  
dim=30
Fun=Function.
MAX=np.repeat(1,dim)
MIN=np.repeat(-1,dim)
'''

PAR=len(MAX) #NUM DE PARAMETROS A SER OTIMIZADOS

# %%
#print(bounds[20][1])

# %%
##################################### IMPORTAR MÓDULOS



NMAX=1000 # maximo tamanho da populacao

dimensions=len(MAX)

start_time = time.time() #INICIALIZA CONTAGEM DO TEMPO
its=10 # quantas vezes vai usar o NPAR antes de alterar de novo
ITE=10 # PONTOS quantas vezes vai alteral NPAR 
#PARTIC=[10,80,10,400,100,100,100,100,100,100]
#ITE=50 # so para testar

#TOTAL=7*dim*its*ITE
TOTAL=10*dim*its*ITE

PARTIC=np.zeros(ITE)

for i in range(RUNS):
  SOMA=0
  pop = np.random.rand(NMAX, dimensions)
  diff=np.zeros(PAR)
  for ii in range(PAR):
    diff[ii] = MAX[ii]-MIN[ii]
  X = MIN + pop * diff
  
  '''for k in range(ITE):
    NPAR=np.copy(PARTIC[k])
    X,BEST,FOBEST,XY,BEST_XY,SOMA= de_rotina_ago_29_2019.de(MAX,MIN, mut, crossp, NPAR, its,Fun,X,SOMA,TOTAL)'''
    
  PONTOS=ITE # DIVISOES DA POPULACAO
 
 ############################################################
  #bounds=[(5*dim, 15*dim)] * PONTOS # ITE
  #bounds=[(3*dim, 12*dim)] * PONTOS # ITE
  #bounds=[(4*dim, 16*dim)] * PONTOS
  
  p=int(TOTAL/its/ITE) 
  bounds=[(p, p)] * PONTOS
    
  maxiter=50
  popsize=50

  '''
  #Geral
  new_mut=(0,1)
  new_crossp=(0,1)
  '''
  #'''
  #Multimodal Separável 
  new_mut=(0.5,1)
  new_crossp=(0,0.5)
  #'''
  '''
  #Multimodal Não Separável 
  new_mut=(0.5,1)
  new_crossp=(0.5,1)
  '''
  '''
  ##### Unimodal Separável
  new_mut=(0,0.5)
  new_crossp=(0,0.5)
  '''
  '''
  ##### Unimodal Não Separável
  new_mut=(0,0.5)
  new_crossp=(0.5,1)
  '''
 ############################################################ 
  
  for j in range(PONTOS):
    bounds.append(new_mut)
    
  for j in range(PONTOS):
    bounds.append(new_crossp)

  new_mut=(0.5,1)
  new_crossp=(0,0.5)
  Fr=np.zeros(its)
  Cr=np.zeros(its)
  for i in range(its):
    Cr[i]=new_mut[0]+(new_mut[1]-new_mut[0])*np.random.random()
    Fr[i]=new_mut[0]+(new_mut[1]-new_mut[0])*np.random.random()
  Cr=0;Fr=0;NP=p;
  PARTIC=np.zeros(its*3)
  for i in range(its):
    Cr=new_crossp[0]+(new_crossp[1]-new_crossp[0])*np.random.random()
    Fr=new_mut[0]+(new_mut[1]-new_mut[0])*np.random.random()
    PARTIC[i]=NP
    PARTIC[i+10]=Fr
    PARTIC[i+20]=Cr

  #MIN[j]+(MAX[j]-MIN[j])*np.random.random()
  
  # PARTIC = aleatorio X a ser otimizada
  mut=0.5;  crossp=0.5;
  #print(PARTIC)
  X,BEST,FOBEST,XY,BEST_XY= de_revisited_bounds.de(bounds, mut, 
                                                   crossp,popsize, maxiter,
                                                   fobj_de,PARTIC)
  # zero X,BEST,FOBEST,XY,BEST_XY= de_rotina_out_11_2019.de(bounds, mut, crossp,popsize, maxiter,Fun,X)

  #ret = optimize.differential_evolution(fobj_de,bounds,init="latinhypercube", # obs: init="random"
  #                                      maxiter=maxiter, popsize=popsize,recombination=0.5)
  Y=BEST_XY#ret.x
  #for k in range(PONTOS):
  #  PARTIC[k]=int(Y[k]) ''''''
  
  

  print('OTIMIZAÇÃO DE_','maxiter=',maxiter,'_ popsize=', popsize,'_ bounds=',bounds[0],'_F',new_mut,'_Cr',new_crossp,'_ TOTAL=',TOTAL,'_ Dim=', PAR,"_Min/Max=",MIN[0],"/",MAX[0],'_',Fun.__name__)
  print('ótimo FOBEST=',ret.fun)
  print("Soma=",SOMA)
  #print("Particulas= ",PARTIC) 
  
#print("GlobalParam e Solucao:", BEST,"Função=",FOBEST)
# Out:
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# NPAR= 30
# k= 6
# NPAR= 30
# k= 7
# NPAR= 30
# k= 8
# NPAR= 30
# k= 9
# NPAR= 30
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# NPAR= 30
# k= 6
# NPAR= 30
# k= 7
# NPAR= 30
# k= 8
# NPAR= 30
# k= 9
# NPAR= 30
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# NPAR= 30
# k= 6
# NPAR= 30
# k= 7
# NPAR= 30
# k= 8
# NPAR= 30
# k= 9
# NPAR= 30
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# NPAR= 30
# k= 6
# NPAR= 30
# k= 7
# NPAR= 30
# k= 8
# NPAR= 30
# k= 9
# NPAR= 30
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# NPAR= 30
# k= 6
# NPAR= 30
# k= 7
# NPAR= 30
# k= 8
# NPAR= 30
# k= 9
# NPAR= 30
# k= 0
# NPAR= 30
# k= 1
# NPAR= 30
# k= 2
# NPAR= 30
# k= 3
# NPAR= 30
# k= 4
# NPAR= 30
# k= 5
# ...

# %%
print(PARTIC)

# %%
#print(new_mut[0])
#print(new_crossp)
Cr=0;Fr=0;NP=0;
PARTIC=np.zeros(its*3)
for i in range(its):
  Cr=new_crossp[0]+(new_crossp[1]-new_crossp[0])*np.random.random()
  Fr=new_mut[0]+(new_mut[1]-new_mut[0])*np.random.random()
  NP=100
  PARTIC[i]=NP
  PARTIC[i+10]=Fr
  PARTIC[i+20]=Cr
print(Cr)
print(Fr)
print(NP)
print(PARTIC)

# %%
print(BEST_XY)

# %%
print(len(bounds))

# %%
TIME = (time.time() - start_time)
print(TIME/60,'minutos')

# %%
s=PARTIC*its
somaa=s.sum()
print('SOMA PARTIC=',somaa)

# %%
  SOMA=0 
    
  pop = np.random.rand(NMAX, dimensions)
  diff=np.zeros(PAR)
  for ii in range(PAR):
    diff[ii] = MAX[ii]-MIN[ii]
  X = MIN + pop * diff

  ind_mut=ITE-1
  ind_crossp=2*ITE-1
  
  for k in range(ITE):
    ind_mut=ind_mut+1
    ind_crossp=ind_crossp+1 
    NPAR=np.copy(int(PARTIC[k]))
    mut=np.copy(Y[ind_mut])
    crossp=np.copy(Y[ind_crossp])
    X,BEST,FOBEST,XY,BEST_XY,SOMA= de_rotina_ago_29_2019.de(MAX,MIN, mut, crossp, NPAR, its,Fun,X,SOMA,TOTAL) 
 

  #print('OTIMIZAÇÃO DE_','maxiter=',maxiter,'_ popsize=', popsize,'_ bounds=',bounds[0],'_ TOTAL=',TOTAL,'_ Dim=', PAR,"_Min/Max=",MIN[0],"/",MAX[0],'_',Fun.__name__)
  print("Best", BEST)
  print("Funcao=",FOBEST)
  print("Soma=",SOMA)
  #print("Particulas= ",PARTIC)

# %%
Y=ret.x
#print(Y)

# %%
print('PARTIC=[',end = '')
for i in range(len(Y)):
  if i<ITE:
    print(int(Y[i]),',',end = '')
  else:
    print(Y[i],',',end = '')
print(']',end = '')

# %%
#print(mut)
#print(crossp)

mut=0.5
crossp=0.5

SOMA=0
pop = np.random.rand(NMAX, dimensions)
diff=np.zeros(PAR)
for ii in range(PAR):
  diff[ii] = MAX[ii]-MIN[ii]
X = MIN + pop * diff
#PARTIC=[100,100,100,100,100,100,100,100,100,100]

#######################################################3

p=int(TOTAL/its/ITE)
PARTIC=np.repeat(p,ITE)
#######################################################

for k in range(ITE):
    NPAR=np.copy(int(PARTIC[k]))
    #print(NPAR)
    X,BEST,FOBEST,XY,BEST_XY,SOMA= de_rotina_ago_29_2019.de(MAX,MIN, mut, crossp, NPAR, its,Fun,X,SOMA,TOTAL) 
print("GlobalParam e Solucao:", BEST,"Funcao=",FOBEST)
print("Soma=",SOMA)
print("Particulas= ",PARTIC)
